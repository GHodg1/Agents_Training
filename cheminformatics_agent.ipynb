# %% [markdown]
# # Cheminformatics Agent
#
# Build using the template for smolagents and using the same LLM (QWEN2.5-32B-Instruct) from API inference. This agent is able to query pubchem for names and return specific molecule data.

# %%
# Set up import path to the project root and load the agent
from pathlib import Path
import sys, os

# Ensure the project root is on sys.path
project_root = Path.cwd()
sys.path.insert(0, str(project_root))

# Map AGENT_API_TOKEN to HF_TOKEN if needed for Hub auth (no secret printed)
if not (os.getenv("HF_TOKEN") or os.getenv("HUGGING_FACE_HUB_TOKEN")):
    if os.getenv("AGENT_API_TOKEN"):
        os.environ["HF_TOKEN"] = os.getenv("AGENT_API_TOKEN")

from First_Cheminformatics_agent.app import agent

# Define the user query
user_query = "What is the IUPAC name of paracetamol?"
# Run the agent with the user query
response = agent.run(user_query)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the IUPAC name of paracetamol?                                                                          │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   paracetamol_iupac_name = pubchem_resolve(query="paracetamol", output_format="iupac_name")
#   print(paracetamol_iupac_name)
# ...

# %%
# Define the user query
user_query = "What is the InChi key of paracetamol?"
# Run the agent with the user query
response = agent.run(user_query)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the InChi key of paracetamol?                                                                           │
# │                                                                                                                 │
# ╰─ HfApiModel - Qwen/Qwen2.5-Coder-32B-Instruct ──────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   paracetamol_inchikey = pubchem_resolve(query="paracetamol", output_format="inchikey")
#   print(paracetamol_inchikey)
# ...
